# %%
import requests
import networkx as nx

# Getting the mount data from Final Fantasy 14 API
r = requests.get('https://ffxivcollect.com/api/mounts')
if r.status_code == 200:
    data = r.json()
else:
    print("There was an error")

# %%
data
# Out:
# {'query': {},
#  'count': 269,
#  'results': [{'id': 340,
#    'name': 'Island Adenium',
#    'description': "Summon forth your island adenium. Literally a desert rose by another name, and doesn't have much of a scent to brag about.",
#    'enhanced_description': "Sprouted and grown in the South Mandra Kingdom, this adenium lived what he thought was a happy life until he encountered the Peerifool. From the castaway vegetable, he learned about the great wide world beyond the island's bounds, and began to dream of embarking upon grand adventures.",
#    'tooltip': "I have oft heard it said that a blossom's beauty can move a man to love and long, but I never truly believed it until I met you two desert roses.    - Thancred",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 278,
#    'order_group': 99,
#    'patch': '6.5',
#    'item_id': 41650,
#    'tradeable': True,
#    'owned': '0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/340.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/340.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': '200 Vegetal Vouchers',
#      'related_type': None,
#      'related_id': None},
#     {'type': 'Island Sanctuary',
#      'text': 'Sanctuary Materiel Container',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 339,
#    'name': 'Island Peerifool',
#    'description': 'Summon forth your island Peerifool. If anyone asks, it bears no relation whatsoever to a certain malicious rotting vegetable.',
#    'enhanced_description': 'Loaded aboard a trading vessel as part of its provisions, this mandragora decided to try her luck in the open sea rather than be added to soup. As luck would have it, the tides delivered her to a desert island, whose fertile soil and sunshine allowed her to attain enormous proportions.',
#    'tooltip': "Honestly, I've never seen such foolishness!    - Namono Tayamono",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 277,
#    'order_group': 99,
#    'patch': '6.5',
#    'item_id': 41649,
#    'tradeable': True,
#    'owned': '0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/339.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/339.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': 'Sanctuary Materiel Container',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 336,
#    'name': 'Peatie',
#    'description': 'Summon forth Peatie, a goobbue maiden with a soft spot for peach blossoms.',
#    'enhanced_description': "Hailing from a place where the peach trees bloom, this winsome goobbue maiden was found and taken in by the traveling entertainer Aldemund. After delighting the crowds on Little Ladies' Day, it made the decision to join you on your adventures in order to spread more cheer.",
#    'tooltip': 'Place these peach blossoms in your hair, and become as princesses!    - Aldiytha',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 274,
#    'order_group': 6,
#    'patch': '6.5',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/336.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/336.png',
#    'bgm': None,
#    'sources': [{'type': 'Event',
#      'text': "Little Ladies' Day (2024)",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 335,
#    'name': 'Garlond GL-IIT',
#    'description': 'Summon forth your Garlond GL-IIT, a magitek vehicle equipped with a tiller, and cultivate your isle in style.',
#    'enhanced_description': 'A variant of the popular Garlond GL-II, this trike has been engineered for cultivating the land. The ceruleum-powered rotary tiller makes short work of transforming rough terrain, while the cargo tray is ideal for transporting materials and passengers both.',
#    'tooltip': 'This untamed isle is yours to cultivate as you see fit.    - Tataru',
#    'movement': 'Terrestrial',
#    'seats': 2,
#    'order': 273,
#    'order_group': 1240,
#    'patch': '6.5',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '1.3%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/335.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/335.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "100,000 Seafarer's Cowries - Rank 20",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 333,
#    'name': 'Sabotender De La Luna',
#    'description': 'Summon forth your sabotender de la luna mount, a prodigious cactuar raised on a diet of rousing tales.',
#    'enhanced_description': 'Under the patronage of its mistress, Rowena, this cactuar has led a pampered life. With the merchant being too busy to personally tend to it, however, its care fell to Khloe Aliapoh, whose attentive hand and rousing tales allowed it to grow into a large specimen with a luminescent blossom.',
#    'tooltip': 'The smell of the sea is sending needles up my nose!    - Presumptuous Postmoogle',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 271,
#    'order_group': 106,
#    'patch': '6.5',
#    'item_id': 41494,
#    'tradeable': True,
#    'owned': '0.9%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/333.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/333.png',
#    'bgm': None,
#    'sources': [{'type': 'Wondrous Tails',
#      'text': "1 Khloe's Gold Certificate Of Commendation",
#      'related_type': None,
#      'related_id': None},
#     {'type': 'Wondrous Tails',
#      'text': '600 Faux Leaves',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 332,
#    'name': 'Lynx Of Abyssal Grief',
#    'description': 'Summon forth your lynx of abyssal grief, which could be what a certain dread voidsent born in the depths of the moon might look like as a large, winged feline.',
#    'enhanced_description': "A phantom creation whose being brims with the Darkness that roiled in the depths of the Thirteenth's moon. The motes of Light it sheds calls to mind the yearning for home that drove the dread voidsent Zeromus, but the origins of this familiar are shrouded in abyssal grief.",
#    'tooltip': 'I just...I just want to go home...    - Drest',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 270,
#    'order_group': 2180,
#    'patch': '6.5',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '0.4%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/332.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/332.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Zerom.ogg',
#    'sources': [{'type': 'Trial',
#      'text': 'The Abyssal Fracture (Extreme)',
#      'related_type': 'Instance',
#      'related_id': 20092}]},
#   {'id': 329,
#    'name': 'Crescent Moon',
#    'description': 'Summon forth your crescent moon mount. By all accounts more comfortable to perch upon than one shaped like a full moon.',
#    'enhanced_description': 'Designed in the likeness of a crescent moon, this magicked gondola was being kept in storage in Sharlayan, where it was classified as a gift. While its origin is undisclosed, the automaton that accompanies the contraption offers a telling clue.',
#    'tooltip': 'Gods, I can scarcely believe we went to the moon and back...    - Thancred',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 267,
#    'order_group': 1310,
#    'patch': '6.5',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/329.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/329.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Kyellow.ogg',
#    'sources': [{'type': 'Premium',
#      'text': 'Online Store (Unreleased)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 328,
#    'name': 'Apocryphal Bahamut',
#    'description': "Summon forth your apocryphal Bahamut, an embodiment of the fallen wyrm's burning desire to be free...and apparently carry you on a sofa.",
#    'enhanced_description': "This draconic entity is brought forth by blowing into the horn you received from the wandering minstrel while holding in your heart Bahamut's song recorded by the Heimdall. Thus imbued with hopes and dreams, it desires nothing more than to soar the boundless skies and recognizes your free-spirited self as its master.",
#    'tooltip': 'Let me examine it, that I might ascertain its authenticity.    - Oboro',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 266,
#    'order_group': 2181,
#    'patch': '6.5',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '0.1%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/328.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/328.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_FF4Baha.ogg',
#    'sources': [{'type': 'Quest',
#      'text': 'Wings of Hope',
#      'related_type': 'Quest',
#      'related_id': 70331}]},
#   {'id': 320,
#    'name': 'Rising Phoenix',
#    'description': 'Summon forth your Rising Phoenix, a symbol of rebirth and gratitude both.',
#    'enhanced_description': 'Created as a token of gratitude for the Warrior of Light, this majestic familiar assumes the likeness of the Phoenix, the immortal bird of legend. Upon death, the creature is said to rise again from its own ashes, on account of which it is revered as a symbol of rebirth.',
#    'tooltip': 'The fires of Ifrit─nay─the Phoenix have taken up residence in my heart, where they will continue to burn forevermore!    - Jude',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 256,
#    'order_group': 102,
#    'patch': '6.48',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '34%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/320.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/320.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Kirin.ogg',
#    'sources': [{'type': 'Event',
#      'text': 'The Rising (2023)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 322,
#    'name': 'Shishioji',
#    'description': "Summon forth Shishioji, a prince who just can't wait to be king (again).",
#    'enhanced_description': 'When the mighty Shishio, legendary auspice and king of the nue, was defeated, it shed a fragment of its malevolent will, which took form as this being. Possessing a will of its own, it recognizes you as its superior, and consents to bearing you upon its back.',
#    'tooltip': "Doubtless the lion's share of the credit lies with me.    - Nero tol Scaeva",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 258,
#    'order_group': 104,
#    'patch': '6.45',
#    'item_id': 40388,
#    'tradeable': True,
#    'owned': '1.0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/322.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/322.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_VVD04.ogg',
#    'sources': [{'type': 'V&C Dungeon',
#      'text': 'Another Mount Rokkon',
#      'related_type': 'Instance',
#      'related_id': 37003},
#     {'type': 'V&C Dungeon',
#      'text': 'Trisassant - Old Sharlayan - 100 Shishu Coins',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 321,
#    'name': 'Burabura Chochin',
#    'description': 'Summon forth your burabura chochin, a kindred spirit in wandering.',
#    'enhanced_description': 'Contrary to expectation, this lantern ghost did not care to haunt people, and was content to simply wander Mount Rokkon. When it saw you similarly wandering, it took you for a kindred spirit and decided to follow you wherever the wind should blow.',
#    'tooltip': 'Could they be evil spirits, lying in wait for hapless treasure seekers?    - Zukin',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 257,
#    'order_group': 103,
#    'patch': '6.45',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '9.3%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/321.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/321.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_VVD03.ogg',
#    'sources': [{'type': 'Achievement',
#      'text': 'Mononopeke',
#      'related_type': 'Achievement',
#      'related_id': 3337}]},
#   {'id': 318,
#    'name': 'Garlond GL-IS',
#    'description': 'Summon forth your Garlond GL-IS. Fitted with a sidecar to carry a trusty sidekick.',
#    'enhanced_description': 'A variant of the Garlond GL-I, this magitek vehicle is fitted with a sidecar to allow for two riders, with engine displacement increased to handle the additional weight. Comes with a life-size mascot lovingly crafted by Wedge─but strictly for a limited time only, and while stocks last!',
#    'tooltip': "It's a Garlond through and through.    - Cid",
#    'movement': 'Terrestrial',
#    'seats': 2,
#    'order': 263,
#    'order_group': 1290,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '4.5%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/318.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/318.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Fanfes2023.ogg',
#    'sources': [{'type': 'Premium',
#      'text': 'Online Store',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 282,
#    'name': 'Island Buffalo',
#    'description': 'Summon forth your island buffalo. Tough on the outside but tender on the inside.',
#    'enhanced_description': 'Belonging to a species introduced by pirates as livestock, this mild-mannered beast took to living on your island one day. Though it appears to have reverted to being feral, it is easily won over with food, in gratitude for which it happily bears you upon its back.',
#    'tooltip': "It's one thing to see the buffaloes in a tizzy, but another to think they could have anything to do with the quakes.    - P'ebaloh",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 262,
#    'order_group': 100,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '10%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/282.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/282.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "50,000 Seafarer's Cowries - Rank 16",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 325,
#    'name': 'Lynx Of Fallen Shadow',
#    'description': 'Summon forth your lynx of fallen shadow, which is what a certain knight in black might look like as a large, winged feline.',
#    'enhanced_description': 'A phantom creation whose elemental aspect is tipped strongly towards Darkness. The motes of Light it sheds call to mind the grim resolve of one who bears a great burden, but the origins of this familiar are shrouded in fallen shadow.',
#    'tooltip': 'I may deal from the shadows, but I dislike shadowy dealings.    - Remon',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 261,
#    'order_group': 2180,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '1.2%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/325.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/325.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Golbez.ogg',
#    'sources': [{'type': 'Trial',
#      'text': 'The Voidcast Dais (Extreme)',
#      'related_type': 'Instance',
#      'related_id': 20090}]},
#   {'id': 324,
#    'name': "Magicked Children's Bed",
#    'description': "Summon forth your magicked children's bed, and enjoy the carefree sleep of a child wherever you go.",
#    'enhanced_description': "Crafted especially for children, this magicked bed hovers by virtue of crystals sourced from floating isles, and gives the sensation of sleeping on a cloud. The design is said to be directly inspired by the beds used at Menphina's Arms.",
#    'tooltip': "Keep that up and I'll send you to bed without supper.    - Y'shtola",
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 260,
#    'order_group': 44,
#    'patch': '6.4',
#    'item_id': 40390,
#    'tradeable': True,
#    'owned': '2.5%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/324.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/324.png',
#    'bgm': None,
#    'sources': [{'type': 'Wondrous Tails',
#      'text': "1 Khloe's Gold Certificate Of Commendation",
#      'related_type': None,
#      'related_id': None},
#     {'type': 'Wondrous Tails',
#      'text': '600 Faux Leaves',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 323,
#    'name': 'Shadow Wolf',
#    'description': 'Summon forth your shadow wolf, a nightmare creature that could only be dreamed up by the darkest of souls.',
#    'enhanced_description': "A spawn of darkest shadow, this dread wolf is said to have been created by an evil king to do battle with a hero of eld. Though the truth of the tale cannot be verified, the creature's eyes betray not a hint of hatred towards the Warrior of Light, whom it serves with unfaltering obedience.",
#    'tooltip': 'When brought into the light, the wolf can seem less fearsome.    - Pumpkin-headed Apparition',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 259,
#    'order_group': 105,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '5.3%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/323.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/323.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Kgreen.ogg',
#    'sources': [{'type': 'Premium',
#      'text': 'Online Store',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 319,
#    'name': 'Megaloambystoma',
#    'description': 'Summon forth your megaloambystoma. Or should that be *max*olotl? You decide.',
#    'enhanced_description': 'The fact that this impossibly large ambystoma is fitted with an elaborate saddle strongly suggests it was created to be ridden. However, its presence in Pandæmonium means it was flawed in some way and deemed a failure.',
#    'tooltip': 'It has been an age shhhince we have feashhhted on axolotl.    - Seww',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 255,
#    'order_group': 101,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '3.5%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/319.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/319.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Pandemonium03.ogg',
#    'sources': [{'type': 'Raid',
#      'text': 'Anabaseios: The Twelfth Circle (Savage)',
#      'related_type': 'Instance',
#      'related_id': 30133}]},
#   {'id': 260,
#    'name': 'Island Mandragora Queen',
#    'description': 'Summon forth your island Mandragora Queen, a well-cultivated vegetable fit for a king.',
#    'enhanced_description': "The life of this island-grown princess was forever changed when she met her future husband the island Tomato King, whom the tides had borne to her. Overcoming their difference in origin, they wed and unified the island's vegetables under the banner of the West Mandra Empire.",
#    'tooltip': 'I fear a diet comprised entirely of one type of root vegetable will not hold up to scrutiny...    - Hinageshi',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 243,
#    'order_group': 99,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '10%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/260.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/260.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "18,000 Seafarer's Cowries",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 259,
#    'name': 'Island Tomato King',
#    'description': 'Summon forth your island Tomato King, a sovereign who rules with a strong and juicy─er, just hand.',
#    'enhanced_description': 'Grown in sunny Vylbrand, this king among produce was being shipped to distant lands when his crate was cast overboard in rough seas. He eventually arrived at a desert island, where he triumphed in a war with avaricious avians and won the heart of a local princess, together with whom he established the West Mandra Empire.',
#    'tooltip': "I dunno about you, but I ain't so keen on the notion of callin' a bloody tomato *Yer Grace*.    - Tiny Trader",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 242,
#    'order_group': 99,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '10%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/259.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/259.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "18,000 Seafarer's Cowries",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 258,
#    'name': 'Island Garlic Jester',
#    'description': 'Summon forth your island Garlic Jester, a mandragora as pungent as it is humorous.',
#    'enhanced_description': 'Possessed of a humorous wit, this mandragora encountered the island Tomato King when they were both adrift. During that time, he amused his sovereign with dozens of droll tales, and in recognition for his services, he was appointed the court jester after the founding of the West Mandra Empire.',
#    'tooltip': 'For one with a name more befitting a jester, you fight with the savagery of a rabid demon.    - Moglin',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 241,
#    'order_group': 99,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '10%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/258.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/258.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "18,000 Seafarer's Cowries",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 297,
#    'name': 'Traveling Supporter',
#    'description': "Summon forth your traveling supporter. Proof that there is nothing a pair of bunny ears can't improve.",
#    'enhanced_description': 'This advanced bipedal machina was found wandering the Carteneau Flats by a quartermaster of the Eorzean Alliance. While it bears a striking resemblance to Allagan clockwork soldiers, it appears to have been enhanced by unknown hands (or paws).',
#    'tooltip': "The supporter? I never would have suspected... It's supposed to help us farm carrots, not eat them!    - Watchingway",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 227,
#    'order_group': 1280,
#    'patch': '6.4',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '9.9%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/297.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/297.png',
#    'bgm': None,
#    'sources': [{'type': 'PvP',
#      'text': 'Crystalline Conflict - Series 4 - Level 25',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 285,
#    'name': 'Moon-hopper',
#    'description': 'Summon forth the moon-hopper. Guaranteed to instill a sense of well-being within all those in earshot.',
#    'enhanced_description': "This enhanced version of the supporter was lovingly created by the ever-innovative Inventingway. Not satisfied with merely making it ridable, the Loporrit also fitted a compact speaker that can belt out Dreamingway's feel-good sounds.",
#    'tooltip': "Well, then, let's hop to it!    - Dreamingway",
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 245,
#    'order_group': 1250,
#    'patch': '6.35',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '17%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/285.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/285.png',
#    'bgm': None,
#    'sources': [{'type': 'Tribal',
#      'text': 'Coiningway - Mare Lamentorum - 18 Loporrit Carats (Rank 7)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 308,
#    'name': 'Aeturna',
#    'description': 'Summon forth the aeturna, an imposing feline that boasts far more than the standard nine lives.',
#    'enhanced_description': "During an expedition to Ilsabard in his younger years, Emperor Xande is said to have come upon this fearsome beast. As its name, meaning “eternal,” would suggest, it possesses remarkable vitality, and in addition to serving as an armored warbeast, it was also a subject in the Allagans' research into immortality.",
#    'tooltip': 'Eternal life can be yours, ladies and gentlemen!    - Silver-tongued Broker',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 244,
#    'order_group': 52,
#    'patch': '6.35',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '1.3%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/308.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/308.png',
#    'bgm': None,
#    'sources': [{'type': 'Achievement',
#      'text': 'Vintage Vogue',
#      'related_type': 'Achievement',
#      'related_id': 3185}]},
#   {'id': 292,
#    'name': 'Orthos Craklaw',
#    'description': 'Summon forth your Orthos craklaw. May or may not have participated in famous battles which actually took place in history.',
#    'enhanced_description': 'Discovered in Eureka Orthos, this specimen of craklaw was imbued with magic in a bid to further harden its carapace. Though that experiment ended in failure, by way of a peculiar side effect, it has attained the power of flight.',
#    'tooltip': 'What you after? Fish? Crab?    - Eybor',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 224,
#    'order_group': 95,
#    'patch': '6.35',
#    'item_id': 36911,
#    'tradeable': True,
#    'owned': '3.4%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/292.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/292.png',
#    'bgm': None,
#    'sources': [{'type': 'Deep Dungeon',
#      'text': 'Eureka Orthos - Gold Sack',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 286,
#    'name': 'Island Alligator',
#    'description': 'Summon forth your island alligator. Demands to be seen not later, but always.',
#    'enhanced_description': 'Hailing from unknown shores, this alligator appeared on your island one day and made itself at home. It takes pride in the fact that its kind is rare out at sea, and willingly carries a rider upon its back if only so it can parade itself in front of all and sundry.',
#    'tooltip': "A face you could kiss─if it weren't covered in scales, that is!    - Foerzagyl",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 254,
#    'order_group': 98,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '14%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/286.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/286.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "35,000 Seafarer's Cowries - Rank 12",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 317,
#    'name': 'Chrysomallos',
#    'description': "Summon forth Chrysomallos, the golden ram of legend─though legend doesn't seem to say anything about illusory coins spilling forth endlessly...",
#    'enhanced_description': "Instead of the white commonly seen in its kind, the fleece of this sheep is a remarkable golden hue. While the seller insisted that it is the golden ram of legend, as with all such claims, this should be taken with a pinch of salt. Only time and perhaps a new growth of wool will reveal the creature's true nature.",
#    'tooltip': 'To think sheep can thrive in so remote a place as this...    - Cirina',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 253,
#    'order_group': 73,
#    'patch': '6.3',
#    'item_id': 39494,
#    'tradeable': True,
#    'owned': '1.0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/317.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/317.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Golden.ogg',
#    'sources': [{'type': 'Purchase',
#      'text': 'Edelina - Mor Dhona - 50,000,000 Gil',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 316,
#    'name': 'Magitek Avenger G1',
#    'description': 'Call into battle your magitek avenger G1, an imperial warmachina made gaudier by goblin hands.',
#    'enhanced_description': 'Rumor holds that a golden sasquatch statue stands at the heart of the Garlean capital, from which magitek weapons would emerge to defend the city should it fall under attack. The veracity of the tale aside, the goblins liked it enough that they decided to create this golden avenger to match the statue.',
#    'tooltip': 'I saw a golden opportunity just begging to be seized...    - Tataru',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 252,
#    'order_group': 1030,
#    'patch': '6.3',
#    'item_id': 39493,
#    'tradeable': True,
#    'owned': '1.0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/316.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/316.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Golden.ogg',
#    'sources': [{'type': 'Purchase',
#      'text': 'Edelina - Mor Dhona - 50,000,000 Gil',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 315,
#    'name': 'Lynx Of Righteous Fire',
#    'description': 'Summon forth your lynx of righteous fire, which could be what a certain honor-bound archfiend might look like as a large, winged feline.',
#    'enhanced_description': 'A phantom creation whose elemental aspect is tipped strongly towards astral fire. Its fiery body calls to mind the ardor of Rubicante, archfiend of fire, but the origins of this familiar are shrouded in impenetrable flames.',
#    'tooltip': 'It is time you were purified in the raging blaze of His blessing!    - Zagozz Teh',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 251,
#    'order_group': 2180,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '2.2%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/315.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/315.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Rubi.ogg',
#    'sources': [{'type': 'Trial',
#      'text': 'Mount Ordeals (Extreme)',
#      'related_type': 'Instance',
#      'related_id': 20087}]},
#   {'id': 314,
#    'name': 'Pinky',
#    'description': 'Summon forth Pinky, an elephantine machine engineered to enrapture.',
#    'enhanced_description': 'Upon hearing that inebriated folk are wont to have visions of a delightful pink elephant, the Loporrits were inspired to make the creature a reality. The tale was, of course, simply a joke at their expense, but if this machine brings a smile to even one person, then their efforts will not have been in vain.',
#    'tooltip': 'This pink color is perfect!    - Auri Boy',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 250,
#    'order_group': 30,
#    'patch': '6.3',
#    'item_id': 39491,
#    'tradeable': True,
#    'owned': '1.2%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/314.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/314.png',
#    'bgm': None,
#    'sources': [{'type': 'Treasure Hunt',
#      'text': 'Nesvaaz - Radz-at-Han - 3 Bottles Of Exciting Tonic (The Excitatron 6000 - Gold Chests)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 313,
#    'name': 'Phaethon',
#    'description': 'Summon forth fiery Phaethon, a legendary beast of Corvosi myth.',
#    'enhanced_description': 'According to Corvosi myth, simply being near this fiery steed is akin to bathing in hot coals, and it is only through the ingenuity of alchemy that one can ride it unscathed. A nigh-identical being, created to draw a carriage in the heavens, is said to have existed in the world unsundered, but it is uncertain what manner of connection, if any, exists between the two beasts.',
#    'tooltip': 'BURN! BURN! ALL IS BURN!    - Gogmagolem',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 249,
#    'order_group': 54,
#    'patch': '6.3',
#    'item_id': 39490,
#    'tradeable': True,
#    'owned': '3.4%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/313.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/313.png',
#    'bgm': None,
#    'sources': [{'type': 'Treasure Hunt',
#      'text': 'Nesvaaz - Radz-at-Han - 3 Burning Horns (The Shifting Gymnasion Agonon - Gold Chests)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 312,
#    'name': 'Blackjack',
#    'description': 'Summon forth the *Blackjack*, or rather, its scale prototype. Exactly where inside it you ride is a mystery best left unanswered.',
#    'enhanced_description': 'Commissioned by Chairman Tatabaru of Highwind Skyways to develop a new airship, the engineers of Garlond Ironworks produced this scale prototype for testing purposes. Despite its diminutive size, it boasts an impressive loading capacity, and can easily carry you and a few friends.',
#    'tooltip': "Good gods, it's the *Blackjack*!    - Tataramu",
#    'movement': 'Airborne',
#    'seats': 4,
#    'order': 248,
#    'order_group': 1270,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '3.7%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/312.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/312.png',
#    'bgm': None,
#    'sources': [{'type': 'Gold Saucer',
#      'text': '4,000,000 MGP',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 311,
#    'name': 'Anden III',
#    'description': 'Summon forth Anden III. It has a mouth, but it cannot scream.',
#    'enhanced_description': 'In gratitude for your kindness, the pixie Eo Tyr gifted you this peculiar ambulatory plant, which they created from the leaves of the original Anden after pruning him. While it resembles its namesake, it lacks the power of speech, and there is no telling what thoughts lie behind its permanently horrified expression.',
#    'tooltip': 'Kind-hearted as we pixies are, we decided to turn him into a lovely leafman!    - Sheep-obsessed Pixie',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 247,
#    'order_group': 98,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '18%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/311.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/311.png',
#    'bgm': None,
#    'sources': [{'type': 'Quest',
#      'text': 'A Labor of Leaf',
#      'related_type': 'Quest',
#      'related_id': 70253}]},
#   {'id': 310,
#    'name': 'Set Of Ceruleum Balloons',
#    'description': 'Summon forth your set of ceruleum balloons. Propulsion not included.',
#    'enhanced_description': "Filled with gasified ceruleum, this festive assortment of balloons boasts enough buoyancy to lift a full-grown Roegadyn off the ground. However, it possesses no means of propulsion, and one is required to provide one's own wind magicks to move.",
#    'tooltip': "Squawk! Bring balloon directly over unbelievers' dung heap!    - Ixali Chieftain",
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 246,
#    'order_group': 1260,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '3.5%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/310.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/310.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Kyellow.ogg',
#    'sources': [{'type': 'Premium',
#      'text': 'Online Store',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 301,
#    'name': 'Magicked Parasol',
#    'description': 'Summon forth your magicked parasol, and have the whole world at your feet.',
#    'enhanced_description': 'This flying parasol was created by a certain elderly mage in her youth. Intending to sell them en masse to fund her research, she chose a pink parasol─popular in those days─as the base. Due to the need for considerable magical power and grip strength to use them, however, she experienced only modest success.',
#    'tooltip': "Perhaps you'll need a parasol the next time you visit!    - Sparkling-eyed Loporrit",
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 231,
#    'order_group': 1220,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '1.4%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/301.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/301.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Kyellow.ogg',
#    'sources': [{'type': 'Premium',
#      'text': 'Online Store',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 300,
#    'name': 'Magicked Umbrella',
#    'description': 'Summon forth your magicked umbrella to whisk you off your feet in the most delightful way.',
#    'enhanced_description': 'This flying umbrella was created by a certain elderly mage in her youth. It uses a black umbrella as the base, the better for blending into the night and sneaking into the Great Gubal Library from above. Its creator, it would seem, has always had a rebellious streak.',
#    'tooltip': 'You can stand under my umbrella.    - Kindly Maiden',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 230,
#    'order_group': 1220,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '2.0%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/300.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/300.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Kyellow.ogg',
#    'sources': [{'type': 'Premium',
#      'text': 'Online Store',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 167,
#    'name': 'Logistics Node',
#    'description': 'Call into battle your Allagan logistics node. For your safety and the safety of those around you, all weaponry has been disabled.',
#    'enhanced_description': 'One of the automated system drones deployed by the Allagans to oversee logistics in their strongholds. After being unearthed by the Sons of Saint Coinach, the mechanical sphere was off-loaded to the Eorzean Alliance and modified into a personal transportation device.',
#    'tooltip': 'Allagan technology, eh?    - Fyrgeiss',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 125,
#    'order_group': 1000,
#    'patch': '6.3',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '16%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/167.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/167.png',
#    'bgm': None,
#    'sources': [{'type': 'PvP',
#      'text': 'Crystalline Conflict - Series 3 - Level 15',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 304,
#    'name': 'Silkie',
#    'description': 'Summon forth your silkie mount. Because cleanliness is next to cuteness.',
#    'enhanced_description': "Encountered in the depths of the Sil'dihn Subterrane, this arcane entity was the familiar of former sultana Nanasha Ul Nasha, who created it to keep the royal palace squeaky clean. Contrary to its appearance, the pom on the tail is the actual being rather than the mouselike creature.",
#    'tooltip': "I'm countin' on ye to clean up this mess.    - Bloeidin",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 234,
#    'order_group': 97,
#    'patch': '6.25',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '17%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/304.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/304.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_VVD01.ogg',
#    'sources': [{'type': 'Achievement',
#      'text': "Dig Deep: The Sil'dihn Subterrane",
#      'related_type': 'Achievement',
#      'related_id': 3153}]},
#   {'id': 303,
#    'name': "Sil'dihn Throne",
#    'description': "Summon forth your Sil'dihn throne. Once seating the rulers of Sil'dih, it now serves as your personal mode of transport.",
#    'enhanced_description': "Discovered in a sector of the Sil'dihn Subterrane, this magnificent throne is believed to have been a spare. It moves in response to its master's will, but whether it does so via the spirits of Sil'dihns long dead or simple magicks is unknown.",
#    'tooltip': 'H-How could you mistake me for that overstuffed throne-warmer!?    - Moghan',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 233,
#    'order_group': 1230,
#    'patch': '6.25',
#    'item_id': 38461,
#    'tradeable': True,
#    'owned': '2.1%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/303.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/303.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_VVD02.ogg',
#    'sources': [{'type': 'V&C Dungeon',
#      'text': "Another Sil'dihn Subterrane",
#      'related_type': 'Instance',
#      'related_id': 37001},
#     {'type': 'V&C Dungeon',
#      'text': "Trisassant - Old Sharlayan - 100 Sil'dihn Silvers",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 298,
#    'name': 'Miw Miisv',
#    'description': 'Summon forth Miw Miisv, living proof that hope springs eternal─and in unexpected shapes.',
#    'enhanced_description': 'Born at Elysion from the hopes of the Ea, this peculiar dynamis life-form possesses a semi-transparent body reminiscent of a jellyfish, and can deliver a sting of sorts with the lightning it harbors. There is no greater pleasure for it than to connect with others in the microcosm of its heart. Literally.',
#    'tooltip': 'Just like jellyfish, they jump, jerk, and jolt to jiggle themselves up.    - Wawalago',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 228,
#    'order_group': 96,
#    'patch': '6.25',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '21%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/298.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/298.png',
#    'bgm': None,
#    'sources': [{'type': 'Tribal',
#      'text': 'N-0598 - Ultima Thule - 18 Omicron Omnitokens (Rank 7)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 257,
#    'name': 'Island Eggplant Knight',
#    'description': 'Summon forth your island Eggplant Knight, an oversized vegetable embodiment of chivalry.',
#    'enhanced_description': 'Hailing from the selfsame land as the Tomato King, the Eggplant Knight shared a crate with the sovereign when they were shipped out. However, he fell overboard when the vessel encountered rough seas, and drifted for days before being deposited on a desert island. Among other feats, he prides himself on having played a key role in the founding of the West Mandra Empire.',
#    'tooltip': 'I thought ye were a feral turnip, a murderous eggplant, or summat like that!    - Tiny Trader',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 240,
#    'order_group': 99,
#    'patch': '6.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '14%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/257.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/257.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "12,000 Seafarer's Cowries",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 256,
#    'name': 'Island Onion Prince',
#    'description': 'Summon forth your island Onion Prince, a vegetable whose colossal size befits his station.',
#    'enhanced_description': "Royalty among mandragora, this island-bred Onion Prince knew every comfort growing up. Such a pampered life led to boredom, however, and he took to whiling away the days in mischief. Dismayed by his son's behavior, the king sent him off to squire for a renowned hero, that he might learn something of responsibility and leadership.",
#    'tooltip': 'By the onion, in my rambling I forgot why I called you over!    - Bloezoeng',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 239,
#    'order_group': 99,
#    'patch': '6.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '14%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/256.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/256.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "12,000 Seafarer's Cowries",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 255,
#    'name': 'Island Mandragora',
#    'description': 'Summon forth your island mandragora, a prime piece of island produce.',
#    'enhanced_description': 'Born into an influential family in the West Mandra Empire, fabled nation of vegetables, this mandragora grew to its prodigious size thanks to fertile soil and abundant sunlight. Alas, its blessed upbringing could also be considered a curse, for it is the fate of such prime produce to go to market.',
#    'tooltip': "I'd be much obliged if you could rid the field of some mandragoras.    - Gurcant",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 238,
#    'order_group': 99,
#    'patch': '6.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '14%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/255.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/255.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "12,000 Seafarer's Cowries",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 277,
#    'name': 'Garlond GL-II',
#    'description': "Summon forth your Garlond GL-II. For those who've got a nice place─who never wanted to be anybody else.",
#    'enhanced_description': 'This prototype magitek vehicle was developed by Garlond Ironworks to be a mode of transportation for a new era. A compact-but-powerful twin-bank ceruleum engine provides effortless acceleration which, coupled with the rugged chassis, allows it to devour rough terrain─such as that one might see on a desert island.',
#    'tooltip': 'Latest technology! Revolutionary ideas!    - Razel Huizan the Stationary',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 237,
#    'order_group': 1240,
#    'patch': '6.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '21%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/277.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/277.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MJI.ogg',
#    'sources': [{'type': 'Island Sanctuary',
#      'text': "24,000 Seafarer's Cowries - Rank 10",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 306,
#    'name': 'Lynx Of Imperious Wind',
#    'description': 'Summon forth your lynx of imperious wind, which could be what a certain tempestuous archfiend might look like as a large, winged feline.',
#    'enhanced_description': 'A phantom creation whose elemental aspect is tipped strongly towards astral wind. Its blustery wings call to mind the caprice of Barbariccia, archfiend of wind, but the origins of this familiar are shrouded in unrelenting storms.',
#    'tooltip': 'Motes against the tempest. In vain do they struggle...    - Sonu Vanu',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 236,
#    'order_group': 2180,
#    'patch': '6.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '3.9%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/306.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/306.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Barb.ogg',
#    'sources': [{'type': 'Trial',
#      'text': "Storm's Crown (Extreme)",
#      'related_type': 'Instance',
#      'related_id': 20085}]},
#   {'id': 305,
#    'name': 'Sunforged',
#    'description': 'Summon forth your sunforged. Its searing flames consume all─with the exception of its owner, thankfully.',
#    'enhanced_description': 'A product of the genius mind of Hephaistos, this fiery phantom creation combines two concepts─a flying snake and an immortal bird─and can shapeshift as the situation demands. Only the individual it recognizes as its master may ride it unscathed.',
#    'tooltip': 'It tastes like burning...    - Hapless Boy',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 235,
#    'order_group': 97,
#    'patch': '6.2',
#    'item_id': None,
#    'tradeable': False,
# ...
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_Ifrit.ogg',
#    'sources': [{'type': 'Trial',
#      'text': 'The Bowl Of Embers (Extreme)',
#      'related_type': 'Instance',
#      'related_id': 20008}]},
#   {'id': 27,
#    'name': 'Bomb Palanquin',
#    'description': 'Summon forth a bevy of bombs who will bear you in comfort upon a hovering palanquin.',
#    'enhanced_description': 'Upon learning that his creations were forever lacking the power to combust, 789th Order Acolyte Ba Go did what any master of explosives would─attach the bombs to the corners of an iron bench and create a floating coach.',
#    'tooltip': 'Hack and slash and tossy-boom. Bang and boom and slashy-doom.♪   - Goblin Diddy',
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 14,
#    'order_group': 12,
#    'patch': '2.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '34%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/27.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/27.png',
#    'bgm': None,
#    'sources': [{'type': 'Tribal',
#      'text': 'Kobold Vendor - 789th Order Dig - 120,000 Gil (Rank 4)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 26,
#    'name': 'Cavalry Elbst',
#    'description': "Summon your cavalry elbst, raised from an egg by Pahh of Novv's Clutch.",
#    'enhanced_description': "To ensure his elbst do not find themselves at a disadvantage to swift-running chocobos, Pahh of Novv's Clutch clips the webbing on their feet at a young age, rendering them more capable of achieving high speeds on land─though they will ever be slower than their brethren while underwater.",
#    'tooltip': 'My elbst is your elbst.   - Pahh',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 13,
#    'order_group': 11,
#    'patch': '2.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '28%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/26.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/26.png',
#    'bgm': None,
#    'sources': [{'type': 'Tribal',
#      'text': "Sahagin Vendor - Novv's Nursery - 120,000 Gil (Rank 4)",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 25,
#    'name': 'Fat Chocobo',
#    'description': 'Summon forth your fat chocobo mount. Take care that there is sufficient room for his ample girth.',
#    'enhanced_description': 'Playfully described by some as “large and in charge,” in truth, when summoned, this gluttonous gourmand will flap nary a feather unless a garland of gysahl greens is dangled before him─in which case not even the laws of nature can slow the fat chocobo down.',
#    'tooltip': 'Huff...huff...heave...heave...   - Fat Chocobo',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 12,
#    'order_group': 2,
#    'patch': '2.2',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '34%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/25.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/25.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_DEBUChocobo.ogg',
#    'sources': [{'type': 'Premium',
#      'text': "A Realm Reborn Collector's Edition",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 22,
#    'name': 'Nightmare',
#    'description': 'Summon forth the single-horned steed with a temperament as black as his coat.',
#    'enhanced_description': 'While it is no secret that it was the enigmatic Ascians who provided the beast tribes with nightmares, their reasons for doing so remain shrouded in mystery. Otherwise untamable, the single piercing tone of a magicked whistle is the only method known to soothe the savage beasts.',
#    'tooltip': 'See the nightmare for reality, and ready thyself for the coming chaos!   - Urianger',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 11,
#    'order_group': 2000,
#    'patch': '2.1',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '46%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/22.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/22.png',
#    'bgm': None,
#    'sources': [{'type': 'Trial',
#      'text': 'The Bowl Of Embers (Extreme)',
#      'related_type': 'Instance',
#      'related_id': 20008},
#     {'type': 'Trial',
#      'text': 'The Howling Eye (Extreme)',
#      'related_type': 'Instance',
#      'related_id': 20010},
#     {'type': 'Trial',
#      'text': 'The Navel (Extreme)',
#      'related_type': 'Instance',
#      'related_id': 20009}]},
#   {'id': 21,
#    'name': 'Gilded Magitek Armor',
#    'description': 'Call into battle your gilded suit of magitek armor. Its golden coating serves to resist magicks while impressing members of the opposite sex.',
#    'enhanced_description': "It only took a few heated skirmishes with the allied city–states for Garlemald to realize that the magicks wielded by the realm's mages were too much for even the thickest of magitek armor plating. Alloyed gilding has since been discovered to dampen the effects of elemental charges and is now standard issue.",
#    'tooltip': 'You ditched your magitek armor!? Fool of a Lalafell!   - Biggs',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 10,
#    'order_group': 4,
#    'patch': '2.1',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '42%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/21.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/21.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MagitekArmor.ogg',
#    'sources': [{'type': 'Achievement',
#      'text': "Everybody's Darling",
#      'related_type': 'Achievement',
#      'related_id': 862}]},
#   {'id': 20,
#    'name': 'Laurel Goobbue',
#    'description': 'Summon your laurel goobbue, towering friend to the sylphs.',
#    'enhanced_description': "After having the moss and flowers growing upon his head pulled up and tossed aside like common weeds by a band of sylvan ne'er-do-wells, this quiet-mannered goobbue was taken in and cared for by the sylphs of Little Solace whose elders crafted for him a magnificent laurel with which to hide his scars.",
#    'tooltip': 'Naught is as exhilarating as a romp through the forest on goobbueback.   - Unknown',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 9,
#    'order_group': 6,
#    'patch': '2.1',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '34%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/20.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/20.png',
#    'bgm': None,
#    'sources': [{'type': 'Tribal',
#      'text': 'Sylphic Vendor - Little Solace - 120,000 Gil (Rank 4)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 19,
#    'name': 'Cavalry Drake',
#    'description': 'Summon your cavalry drake, trained by the drake whisperer of the Brotherhood of Ash.',
#    'enhanced_description': 'Training a cavalry drake is a long and arduous process that begins the moment the scalekin hatches. Never allowed to see its mother, the creature is raised solely in the presence of a drake whisperer while being weaned on the incendiary glands of aged battle drakes to ensure it is both submissive and deadly.',
#    'tooltip': "You are as a lost kitten that has wandered into the drake's lair.   - Zagozz Teh",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 8,
#    'order_group': 10,
#    'patch': '2.1',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '31%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/19.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/19.png',
#    'bgm': None,
#    'sources': [{'type': 'Tribal',
#      'text': "Amalj'aa Vendor - Ring of Ash - 120,000 Gil (Rank 4)",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 18,
#    'name': 'Behemoth',
#    'description': 'Summon your mighty behemoth, trained from birth to carry you...not trample you underfoot like an ant.',
#    'enhanced_description': "Immediately following the Calamity, an adventurer returning to Gridania from Falcon's Nest in Coerthas claims to have happened upon a den of baby behemoths who had lost their mother. Despite objections from friends and family alike, she kept the beasts, eventually training them to serve as mounts.",
#    'tooltip': 'Do not presume to provoke the behemoth to battle. You will die.   - Meurise',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 7,
#    'order_group': 9,
#    'patch': '2.1',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '69%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/18.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/18.png',
#    'bgm': None,
#    'sources': [{'type': 'Achievement',
#      'text': 'Jonathas - Old Gridania - 6 Achievement Certificates',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 15,
#    'name': 'Unicorn',
#    'description': 'Summon forth the single-horned steed you befriended in the Black Shroud.',
#    'enhanced_description': 'Not long ago, Eorzean unicorns numbered in the thousands, and could oft be seen roaming the Coerthas highlands in great majestic herds that would render the mountains white as snow. Poaching has caused the population to decline, and if it were not for your act of kindness, there would be one fewer.',
#    'tooltip': "Your precious horses, they're just unicorns with a big empty forehead.   - Chief Chocowacker",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 6,
#    'order_group': 2000,
#    'patch': '2.0',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '48%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/15.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/15.png',
#    'bgm': None,
#    'sources': [{'type': 'Quest',
#      'text': 'Unicorn Power',
#      'related_type': 'Quest',
#      'related_id': 65730}]},
#   {'id': 9,
#    'name': 'Ahriman',
#    'description': 'Summon forth a riding ahriman, bound to this realm with powerful magicks guaranteed to never fade.',
#    'enhanced_description': 'Though little is known of the void and the creatures which call the extra-dimensional realm home, scholars have discovered that there is a strict hierarchy amongst voidsent consisting of twelve distinct tiers. Ahrimans are believed to fall into the fifth, making them formidable foes...when not enthralled by curses.',
#    'tooltip': "Ye'd 'ave t' be blinder'n an ahriman wi' an eyepatch t' miss the camp.   - Baderon Tenfingers",
#    'movement': 'Airborne',
#    'seats': 1,
#    'order': 5,
#    'order_group': 8,
#    'patch': '2.0',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '60%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/9.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/9.png',
#    'bgm': None,
#    'sources': [{'type': 'Achievement',
#      'text': 'Jonathas - Old Gridania - 6 Achievement Certificates',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 8,
#    'name': 'Coeurl',
#    'description': 'Summon your fleet-footed battle coeurl, trained from a pup to recognize you as a friend...not food.',
#    'enhanced_description': "Native to the jungles of the Near East, coeurls were only recently introduced to Eorzea, brought over from faraway lands such as Thavnair by Ul'dahn nobles who thought to breed them as pets. Now, but a handful of skilled tamers living in recluse on the Pearl are said to be able to train them.",
#    'tooltip': "Hey, good lookin'! Catch my coeurl yet?   - Swygrael",
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 4,
#    'order_group': 7,
#    'patch': '2.0',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '34%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/8.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/8.png',
#    'bgm': None,
#    'sources': [{'type': 'Premium',
#      'text': "A Realm Reborn Collector's Edition",
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 6,
#    'name': 'Magitek Armor',
#    'description': 'Call into battle your suit of Garlond Ironworks-modified magitek armor.',
#    'enhanced_description': 'This suit of Garlean-developed reaper-class magitek battle armor has had its original control systems purged and replaced with a new, modified core built by Cid of the Garlond Ironworks.',
#    'tooltip': 'At last, our very own suit of magitek armor!   - Cid Garlond',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 3,
#    'order_group': 4,
#    'patch': '2.0',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '91%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/6.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/6.png',
#    'bgm': 'https://ffxivcollect.com/music/BGM_Ride_MagitekArmor.ogg',
#    'sources': [{'type': 'Quest',
#      'text': 'The Ultimate Weapon',
#      'related_type': 'Quest',
#      'related_id': 66060}]},
#   {'id': 5,
#    'name': 'Legacy Chocobo',
#    'description': 'Five years and a realm-shaking Calamity were not enough to break the bonds between you and your loyal steed. A single whistle and he will be at your side once again.',
#    'enhanced_description': 'In the five years following your sudden disappearance from the Carteneau Flats, your ever-faithful chocobo spent each waking moment galloping across the realm in search of his lost master. His myriad adventures are nothing less than fantastical and heartbreaking...but that is a story for another day.',
#    'tooltip': 'Go find the chocobo you rode in on, and ride on out.   - Sevrin',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 2,
#    'order_group': 1,
#    'patch': '2.0',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '1.4%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/5.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/5.png',
#    'bgm': None,
#    'sources': [{'type': 'Limited',
#      'text': 'Legacy Campaign',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 4,
#    'name': 'Goobbue',
#    'description': 'Use the odd-shaped horn gifted to you by the wandering minstrel to call a massive goobbue to your side.',
#    'enhanced_description': 'Traded for a song by the High Satrap of a distant land, the secret to taming these creatures once thought to be unbreakable was introduced to Eorzea by a mysterious wandering minstrel who journeyed through the realm in the final days before the Calamity.',
#    'tooltip': 'Would that I had the girth of a goobbue!   - Nanamo Ul Namo',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 1,
#    'order_group': 6,
#    'patch': '2.0',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '0.8%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/4.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/4.png',
#    'bgm': None,
#    'sources': [{'type': 'Limited',
#      'text': 'At level 30 or above, speak with the Wandering Minstrel in Eastern La Noscea (1.0)',
#      'related_type': None,
#      'related_id': None}]},
#   {'id': 1,
#    'name': 'Company Chocobo',
#    'description': 'Summon your Grand Company-issued battle chocobo.',
#    'enhanced_description': "Born and bred in the city–state of Ishgard, the majority of company chocobos are geldings of the rouncey variety; however, massive destriers and miniature Belah'dian jennets are also raised to accommodate the builds of Roegadyn and Lalafellin riders respectively.",
#    'tooltip': 'Chocobos are stout- hearted creatures, but they have their limits.   - Mimigun',
#    'movement': 'Terrestrial',
#    'seats': 1,
#    'order': 0,
#    'order_group': 1,
#    'patch': '2.0',
#    'item_id': None,
#    'tradeable': False,
#    'owned': '97%',
#    'image': 'https://ffxivcollect.com/images/mounts/large/1.png',
#    'icon': 'https://ffxivcollect.com/images/mounts/small/1.png',
#    'bgm': None,
#    'sources': [{'type': 'Quest',
#      'text': 'My Little Chocobo (Immortal Flames)',
#      'related_type': 'Quest',
#      'related_id': 66238},
#     {'type': 'Quest',
#      'text': 'My Little Chocobo (Maelstrom)',
#      'related_type': 'Quest',
#      'related_id': 66237},
#     {'type': 'Quest',
#      'text': 'My Little Chocobo (Twin Adder)',
#      'related_type': 'Quest',
#      'related_id': 66236}]}]}

# %%
g = nx.Graph()

for mount in data["results"]:
    # For adding percent node, will be spaced by 5%
    own_percent = str(round(float(mount["owned"][:-1])/5)*5)
    # Adding mount nodes
    g.add_node(mount["id"])
    # Adding percent nodes
    g.add_node(own_percent)
    # Adding connection between a mount and the percentage owned
    g.add_edge(mount["id"], own_percent)
print(len(g.nodes()))
print(len(g.edges()))
# Out:
# 287
# 269

# %%
nx.write_graphml(g, "ff14_mount.graphml")

# %%
top_k = 10
centrality_degree = nx.degree_centrality(g)

# sort node-centrality dictionary and then reverse to get top elements first
for i in sorted(centrality_degree, key=centrality_degree.get, reverse=True)[:top_k]:
    print(i, centrality_degree[i])
# Out:
# 0 0.1853146853146853
# 10 0.15384615384615385
# 5 0.14335664335664336
# 15 0.0979020979020979
# 25 0.07692307692307693
# 20 0.06993006993006994
# 35 0.04895104895104895
# 40 0.038461538461538464
# 30 0.038461538461538464
# 45 0.02097902097902098
